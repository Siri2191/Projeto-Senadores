# %% [markdown]
# <a href="https://colab.research.google.com/github/Siri2191/Projeto-Senadores/blob/main/Sobre_os_Senadores_em_mandato.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <h1>Contexto: </h1>
#
# ---
#
# No Brasil cada senador é eleito por duas legislaturas de 4 anos, ou seja, o mandato de um senador dura um total de 8 anos, sendo que a cada quatro se renova 2/3 e nos quatro anos seguintes, 1/3 do senado. Dando um total de 1 inteiro a cada 8 anos.
#
# A ideia desta análise e traçar um perfil dos senadores em mandato atual (até 2022), ano de eleição, e após as eleições, comparara se houve alguma diferença no perfil.
#
# Os dados serão tirados do portal da tranparencia do senado.

# %% [markdown]
# # Importando bibliotecas
#
# ---

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import plotly.graph_objects as go 
from datetime import date

# %% [markdown]
# #Importando dados
#
# ---

# %%
df = pd.read_csv("https://www.senado.leg.br/transparencia/LAI/secrh/parla_inter_csv.csv", encoding= '1252',sep=';',header=1)
df.head()
# Out:
#      NOME_PARLAMENTAR  PARTIDO  UF TITULARIDADE      MANDATO  \
# 0        ACIR GURGACZ      PDT  RO      Titular  2015 / 2023
# 1   ALESSANDRO VIEIRA     PSDB  SE      Titular  2019 / 2027
# 2  ALEXANDRE SILVEIRA      PSD  MG  1º Suplente  2015 / 2023
# 3         ALVARO DIAS  PODEMOS  PR      Titular  2015 / 2023
# 4      ANGELO CORONEL      PSD  BA      Titular  2019 / 2027
#
#                       TELEFONES      DTNASC  \
# 0  (61)3303-3131,(61)3303-3132,  25/02/1962
# 1  (61)3303-9011,(61)3303-9014,  03/04/1975
# 2                (61)3303-5717,  15/07/1970
# 3  (61)3303-4059,(61)3303-4060,  07/12/1944
# 4  (61)3303-6103,(61)3303-6105,  03/05/1958
#
#                                  EMAIL                           CHEFE_GAB  \
# 0        sen.acirgurgacz@senado.leg.br     Marcello Augusto Castro Varella
# 1   sen.alessandrovieira@senado.leg.br             Elaine Da Silva Gontijo
# 2  sen.alexandresilveira@senado.leg.br                                   -
# 3         sen.alvarodias@senado.leg.br  Paulo Kepler Duarte Sampaio Júnior
# 4      sen.angelocoronel@senado.leg.br             Natanael Alves Ferreira
#
#   ENDERECO
# 0  SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 1  SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
# 2  SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 3  SENADO FEDERAL ANEXO 2   ALA NILO COELHO 1º PA...
# 4  SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...

# %% [markdown]
# # Distribuição dos sexos no senado
# ---

# %%
df['NOME_PARLAMENTAR'].unique()
# Out:
# array(['ACIR GURGACZ', 'ALESSANDRO VIEIRA', 'ALEXANDRE SILVEIRA',
#        'ALVARO DIAS', 'ANGELO CORONEL', 'CARLOS PORTINHO', 'CARLOS VIANA',
#        'CHICO RODRIGUES', 'CONFUCIO MOURA', 'DANIELLA RIBEIRO',
#        'DARIO BERGER', 'DAVI ALCOLUMBRE', 'EDUARDO BRAGA',
#        'EDUARDO GIRÃO', 'EDUARDO VELLOSO', 'ELIANE NOGUEIRA',
#        'ELIZIANE GAMA', 'ELMANO FÉRRER', 'ESPERIDIÃO AMIN',
#        'FABIANO CONTARATO', 'FERNANDO BEZERRA COELHO', 'FERNANDO COLLOR',
#        'FLÁVIO ARNS', 'FLÁVIO BOLSONARO', 'GIORDANO', 'GUARACY SILVEIRA',
#        'HUMBERTO COSTA', 'IRAJÁ', 'IVETE DA SILVEIRA', 'IZALCI LUCAS',
#        'JADER BARBALHO', 'JAQUES WAGNER', 'JARBAS VASCONCELOS',
#        'JAYME CAMPOS', 'JEAN PAUL PRATES', 'JORGE KAJURU', 'JOSÉ SERRA',
#        'JULIO VENTURA', 'LASIER MARTINS', 'LEILA BARROS', 'LUCAS BARRETO',
#        'LUIS CARLOS HEINZE', 'LUIZ DO CARMO', 'LUIZ PASTORE',
#        'MAILZA GOMES', 'MARA GABRILLI', 'MARCELO CASTRO', 'MARCOS DO VAL',
#        'MARCOS ROGÉRIO', 'MARGARETH BUZETTI', 'MARIA DAS VITÓRIAS',
#        'MARIA DO CARMO ALVES', 'MECIAS DE JESUS', 'NELSINHO TRAD FILHO',
#        'NILDA GONDIM', 'OGARI PACHECO', 'OMAR AZIZ',
#        'ORIOVISTO GUIMARÃES', 'OTTO ALENCAR', 'PAULO PAIM', 'PAULO ROCHA',
#        'PLÍNIO VALÉRIO', 'RAFAEL TENORIO', 'RANDOLFE RODRIGUES',
#        'REGUFFE', 'ROBERTH BRINGEL', 'ROBERTO ROCHA', 'RODRIGO PACHECO',
#        'ROGÉRIO CARVALHO', 'ROMÁRIO', 'SIMONE TEBET', 'SORAYA THRONICKE',
#        'STYVENSON VALENTIM', 'TASSO JEREISSATI', 'TELMÁRIO MOTA',
#        'VANDERLAN CARDOSO', 'VENEZIANO VITAL DO RÊGO',
#        'WELLINGTON FAGUNDES', 'ZENAIDE MAIA', 'ZEQUINHA MARINHO'],
#       dtype=object)

# %%
df['SEXO'] = ['H', 'H', 'H',
       'H', 'H', 'H', 'H',
       'H', 'H', 'M',
       'H', 'H', 'H',
       'H', 'H', 'M',
       'M', 'H', 'H',
       'H', 'H', 'H',
       'H', 'H', 'H', 'H',
       'H', 'H', 'M', 'H',
       'H', 'H', 'H',
       'H', 'H', 'H', 'H',
       'H', 'H', 'M', 'H',
       'H', 'H', 'H',
       'M', 'M', 'H', 'H',
       'H', 'M', 'M',
       'M', 'H', 'H',
       'M', 'H', 'H',
       'H', 'H', 'H', 'H',
       'H', 'H', 'H',
       'H', 'H', 'H', 'H',
       'H', 'H', 'M', 'M',
       'H', 'H', 'H',
       'H', 'H','H', 'M','H']

# %%
df.head()
# Out:
#      NOME_PARLAMENTAR  PARTIDO  UF TITULARIDADE      MANDATO  \
# 0        ACIR GURGACZ      PDT  RO      Titular  2015 / 2023
# 1   ALESSANDRO VIEIRA     PSDB  SE      Titular  2019 / 2027
# 2  ALEXANDRE SILVEIRA      PSD  MG  1º Suplente  2015 / 2023
# 3         ALVARO DIAS  PODEMOS  PR      Titular  2015 / 2023
# 4      ANGELO CORONEL      PSD  BA      Titular  2019 / 2027
#
#                       TELEFONES      DTNASC  \
# 0  (61)3303-3131,(61)3303-3132,  25/02/1962
# 1  (61)3303-9011,(61)3303-9014,  03/04/1975
# 2                (61)3303-5717,  15/07/1970
# 3  (61)3303-4059,(61)3303-4060,  07/12/1944
# 4  (61)3303-6103,(61)3303-6105,  03/05/1958
#
#                                  EMAIL                           CHEFE_GAB  \
# 0        sen.acirgurgacz@senado.leg.br     Marcello Augusto Castro Varella
# 1   sen.alessandrovieira@senado.leg.br             Elaine Da Silva Gontijo
# 2  sen.alexandresilveira@senado.leg.br                                   -
# 3         sen.alvarodias@senado.leg.br  Paulo Kepler Duarte Sampaio Júnior
# 4      sen.angelocoronel@senado.leg.br             Natanael Alves Ferreira
#
#   ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                \
# 0  SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 1  SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
# 2  SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 3  SENADO FEDERAL ANEXO 2   ALA NILO COELHO 1º PA...
# 4  SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
#
#   SEXO
# 0    H
# 1    H
# 2    H
# 3    H
# 4    H

# %%
fig = px.histogram(df, x="SEXO",title ='Distribuição dos Senadores de acordo com o sexo no ano de 2022',text_auto=True)
fig.update_traces(textfont_size=20)           
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="1d02782c-8f7f-4ce4-a532-7ca8545855cd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1d02782c-8f7f-4ce4-a532-7ca8545855cd")) {                    Plotly.newPlot(                        "1d02782c-8f7f-4ce4-a532-7ca8545855cd",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SEXO=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"texttemplate":"%{value}","x":["H","H","H","H","H","H","H","H","H","M","H","H","H","H","H","M","M","H","H","H","H","H","H","H","H","H","H","H","M","H","H","H","H","H","H","H","H","H","H","M","H","H","H","H","M","M","H","H","H","M","M","M","H","H","M","H","H","H","H","H","H","H","H","H","H","H","H","H","H","H","M","M","H","H","H","H","H","H","M","H"],"xaxis":"x","yaxis":"y","type":"histogram","textfont":{"size":20}}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"mesh3d" ...

# %%
fig = px.histogram(df, x="PARTIDO", color="SEXO", title ='Distribuição dos sexos por partido', text_auto = True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="ae253a24-e4bd-40e3-a977-4f3bdda5452c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae253a24-e4bd-40e3-a977-4f3bdda5452c")) {                    Plotly.newPlot(                        "ae253a24-e4bd-40e3-a977-4f3bdda5452c",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SEXO=H<br>PARTIDO=%{x}<br>count=%{y}<extra></extra>","legendgroup":"H","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"H","offsetgroup":"H","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["PDT","PSDB","PSD","PODEMOS","PSD","PL","PL","UNI\u00c3O","MDB","PSB","UNI\u00c3O","MDB","PODEMOS","UNI\u00c3O","PP","PP","PT","MDB","PTB","PODEMOS","PL","MDB","PP","PT","PSD","PSDB","MDB","PT","MDB","UNI\u00c3O","PT","PODEMOS","PSDB","PDT","PODEMOS","PSD","PP","PSC","MDB","MDB","PODEMOS","PL","REPUBLICANOS","PSD","UNI\u00c3O","PSD","PODEMOS","PSD","PT","PT","PSDB","MDB","REDE","S/Partido","UNI\u00c3O","PTB","PSD","PT","PL","PODEMOS","PSDB","PROS","PSD","MDB","PL","PL"],"xaxis":"x","yaxis":"y","type":"histogram"},{"alignmentgroup":"True","bingroup":"x","hovertemplate":"SEXO=M<br>PARTIDO=%{x}<br>count=%{y}<extra></extra>","legendgroup":"M","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"M","offsetgroup":"M","orientation":"v","showlegend":true,"texttemplate":"%{value}","x":["PSD","PP","CIDADANIA","MDB","PDT","PP","PSDB","PP","PSD","PP","MDB","MDB","UNI\u00c3O","PROS"],"xaxis":"x","yaxis":"y","type":"histogram"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"] ...

# %%
pct_h =  df.query('SEXO == "H"')['SEXO'].count()/len(df)*100
pct_m = df.query('SEXO == "M"')['SEXO'].count()/len(df)*100


print('No senado atual, {} % são mulheres e {}% são homens'.format(pct_m, pct_h))
# Out:
# No senado atual, 17.5 % são mulheres e 82.5% são homens

# %% [markdown]
# #Sobre as idades do senado
# ---

# %%
df.dtypes
# Out:
# NOME_PARLAMENTAR                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          object
# PARTIDO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   object
# UF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        object
# TITULARIDADE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              object
# MANDATO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   object
# TELEFONES                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 object
# DTNASC                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    object
# EMAIL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     object
# CHEFE_GAB                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 object
# ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  object
# SEXO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      object
# dtype: object

# %%
df['DTNASC'] = pd.to_datetime(df['DTNASC'],format='%d/%m/%Y',errors = 'coerce')  # transformando data em datetime

df.dtypes
# Out:
# NOME_PARLAMENTAR                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  object
# PARTIDO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           object
# UF                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                object
# TITULARIDADE                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      object
# MANDATO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           object
# TELEFONES                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         object
# DTNASC                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    datetime64[ns]
# EMAIL                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             object
# CHEFE_GAB                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         object
# ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          object
# SEXO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              object
# dtype: object

# %%
 df['IDADE'] = date.today().year - df['DTNASC'].dt.year

# %%
df
# Out:
#            NOME_PARLAMENTAR  PARTIDO  UF TITULARIDADE      MANDATO  \
# 0              ACIR GURGACZ      PDT  RO      Titular  2015 / 2023
# 1         ALESSANDRO VIEIRA     PSDB  SE      Titular  2019 / 2027
# 2        ALEXANDRE SILVEIRA      PSD  MG  1º Suplente  2015 / 2023
# 3               ALVARO DIAS  PODEMOS  PR      Titular  2015 / 2023
# 4            ANGELO CORONEL      PSD  BA      Titular  2019 / 2027
# ..                      ...      ...  ..          ...          ...
# 75        VANDERLAN CARDOSO      PSD  GO      Titular  2019 / 2027
# 76  VENEZIANO VITAL DO RÊGO      MDB  PB      Titular  2019 / 2027
# 77      WELLINGTON FAGUNDES       PL  MT      Titular  2015 / 2023
# 78             ZENAIDE MAIA     PROS  RN      Titular  2019 / 2027
# 79         ZEQUINHA MARINHO       PL  PA      Titular  2019 / 2027
#
#                        TELEFONES     DTNASC  \
# 0   (61)3303-3131,(61)3303-3132, 1962-02-25
# 1   (61)3303-9011,(61)3303-9014, 1975-04-03
# 2                 (61)3303-5717, 1970-07-15
# 3   (61)3303-4059,(61)3303-4060, 1944-12-07
# 4   (61)3303-6103,(61)3303-6105, 1958-05-03
# ..                           ...        ...
# 75  (61)3303-2092,(61)3303-2099, 1962-11-15
# 76  (61)3303-2252,(61)3303-2481, 1970-07-17
# 77  (61)3303-6219,(61)3303-3778, 1957-06-01
# 78  (61)3303-2371,(61)3303-2372, 1954-11-27
# 79                (61)3303-6623, 1959-09-18
#
#                                      EMAIL  \
# 0            sen.acirgurgacz@senado.leg.br
# 1       sen.alessandrovieira@senado.leg.br
# 2      sen.alexandresilveira@senado.leg.br
# 3             sen.alvarodias@senado.leg.br
# 4          sen.angelocoronel@senado.leg.br
# ..                                     ...
# 75      sen.vanderlancardoso@senado.leg.br
# 76  sen.venezianovitaldorego@senado.leg.br
# 77    sen.wellingtonfagundes@senado.leg.br
# 78           sen.zenaidemaia@senado.leg.br
# 79       sen.zequinhamarinho@senado.leg.br
#
#                              CHEFE_GAB  \
# 0      Marcello Augusto Castro Varella
# 1              Elaine Da Silva Gontijo
# 2                                    -
# 3   Paulo Kepler Duarte Sampaio Júnior
# 4              Natanael Alves Ferreira
# ..                                 ...
# 75                                   -
# 76  Daniel Queiroz De Medeiros Chianca
# 77          Fernando Pereira Damasceno
# 78       Maria Lucia Sigmaringa Seixas
# 79         Alexandre Bodani Cavalcante
#
#    ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                \
# 0   SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 1   SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
# 2   SENADO FEDERAL ANEXO 2   ALA TANCREDO NEVES GA...
# 3   SENADO FEDERAL ANEXO 2   ALA NILO COELHO 1º PA...
# 4   SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
# ..                                                ...
# 75  SENADO FEDERAL ANEXO 2   ALA AFFONSO ARINOS GA...
# 76  SENADO FEDERAL ANEXO 1  20º PAVIMENTO         ...
# 77  SENADO FEDERAL ANEXO 1  19º PAVIMENTO         ...
# 78  SENADO FEDERAL ANEXO 1  8º PAVIMENTO          ...
# 79  SENADO FEDERAL ANEXO 2   ALA TEOTÔNIO VILELA G...
#
#    SEXO  IDADE
# 0     H     60
# 1     H     47
# 2     H     52
# 3     H     78
# 4     H     64
# ..  ...    ...
# 75    H     60
# 76    H     52
# 77    H     65
# 78    M     68
# 79    H     63
#
# [80 rows x 12 columns]

# %%
df['IDADE'].describe()
# Out:
# count    80.000000
# mean     62.737500
# std      11.656197
# min      39.000000
# 25%      52.000000
# 50%      64.000000
# 75%      72.000000
# max      84.000000
# Name: IDADE, dtype: float64

# %%
df.loc[df['IDADE']==39]
# Out:
#    NOME_PARLAMENTAR PARTIDO  UF TITULARIDADE      MANDATO  \
# 27            IRAJÁ     PSD  TO      Titular  2019 / 2027
#
#                       TELEFONES     DTNASC                    EMAIL  \
# 27  (61)3303-6469,(61)3303-6474 1983-02-03  sen.iraja@senado.leg.br
#
#                          CHEFE_GAB  \
# 27  Vilmar Bomfim Ayres Da Fonseca
#
#    ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                \
# 27  SENADO FEDERAL ANEXO 1  21º PAVIMENTO         ...
#
#    SEXO  IDADE
# 27    H     39

# %%
df.loc[df['IDADE']==84]
# Out:
#    NOME_PARLAMENTAR PARTIDO  UF TITULARIDADE      MANDATO  \
# 55    OGARI PACHECO   UNIÃO  TO  2º Suplente  2019 / 2027
#
#                                     TELEFONES     DTNASC  \
# 55  (61)3303-6349,(61)3303-6352,(61)3303-6354 1938-07-20
#
#                              EMAIL                   CHEFE_GAB  \
# 55  sen.ogaripacheco@senado.leg.br  Walter Germano De Oliveira
#
#    ENDERECO                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                \
# 55  SENADO FEDERAL ANEXO 1  5º PAVIMENTO          ...
#
#    SEXO  IDADE
# 55    H     84

# %%
fig = px.box(df, x="IDADE",color='SEXO', title='Distribuição das idades por sexo no senado atual')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="25ad26ff-ff8f-4017-9ee6-3367c36420a8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("25ad26ff-ff8f-4017-9ee6-3367c36420a8")) {                    Plotly.newPlot(                        "25ad26ff-ff8f-4017-9ee6-3367c36420a8",                        [{"alignmentgroup":"True","hovertemplate":"SEXO=H<br>IDADE=%{x}<extra></extra>","legendgroup":"H","marker":{"color":"#636efa"},"name":"H","notched":false,"offsetgroup":"H","orientation":"h","showlegend":true,"x":[60,47,52,78,64,49,59,71,74,66,45,62,50,46,80,75,56,65,73,72,41,49,71,65,39,66,78,71,80,71,54,61,80,63,80,58,72,64,73,72,51,44,60,61,84,64,77,75,72,71,67,68,50,50,70,57,46,54,56,45,74,64,60,52,65,63],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"},{"alignmentgroup":"True","hovertemplate":"SEXO=M<br>IDADE=%{x}<extra></extra>","legendgroup":"M","marker":{"color":"#EF553B"},"name":"M","notched":false,"offsetgroup":"M","orientation":"h","showlegend":true,"x":[50,73,45,79,51,46,55,63,79,81,76,52,49,68],"x0":" ","xaxis":"x","y0":" ","yaxis":"y","type":"box"}],                        {"template":{"data":{"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666 ...
